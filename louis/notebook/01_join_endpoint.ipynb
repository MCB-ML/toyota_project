# %% [markdown]
# ## 0. pip install

# %%
pip install pyodbc pandas python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~penai (c:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (c:\Anaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~penai (c:\Anaconda\Lib\site-packages)

# %% [markdown]
# ODBC Driver 17 for SQL Server 확인

# %%
import pyodbc

pyodbc.drivers()
# Out:
# ['SQL Server',
#  'ODBC Driver 17 for SQL Server',
#  'Microsoft Access Driver (*.mdb, *.accdb)',
#  'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'Microsoft Access Text Driver (*.txt, *.csv)',
#  'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)']

# %% [markdown]
# ## 1. connect Agora Warehous

# %%
import pyodbc
import pandas as pd

SERVER = "6orm62c43rguff2mpdxwqy76tu-3meqk2mii2pehfjxfscngx5a6e.datawarehouse.fabric.microsoft.com"

conn_str = f"""
DRIVER={{ODBC Driver 17 for SQL Server}};
SERVER={SERVER},1433;
Encrypt=yes;
TrustServerCertificate=no;
Authentication=ActiveDirectoryInteractive;
Connection Timeout=30;
"""

conn = pyodbc.connect(conn_str)

df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_6708\3858062543.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
#                   current_db
# 0  DataflowsStagingLakehouse

# %%
df_db = pd.read_sql("""
SELECT * FROM TMKR_L.dbo.l_co_users
WHERE dept_cd = 'DT30106'
""", conn)

df_db
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_6708\2263754774.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_db = pd.read_sql("""
#    user_id group_id  dept_cd showroom_id  name title biz_charge    zip  \
# 0   DT1106  DT00000  DT30106         NaN   이민균    03        NaN  05649
# 1   DT0005  DT00000  DT30106         NaN   김찬규    06        NaN  10507
# 2   DT0406  DT00000  DT30106          01   윤희기    03        NaN    NaN
# 3   DT0302  DT00000  DT30106          01   서광현    04        NaN    NaN
# 4   DT0808  DT00000  DT30106         NaN   인제섭    02        NaN    NaN
# 5   DT0811  DT00000  DT30106         NaN   손형문    02        NaN    NaN
# 6   DT0915  DT00000  DT30106         NaN   박민철    03        NaN    NaN
# 7   DT0827  DT00000  DT30106         NaN   김재용    03        NaN    NaN
# ...

# %%
df_db = pd.read_sql("""
SELECT TOP 100 * FROM TMKR_L.dbo.l_svc_propo
WHERE shop_cd = 'DT30106'
""", conn)

df_db
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_6708\2269127176.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_db = pd.read_sql("""
#     shop_cd  propo_dt  propo_seq repair_type_cd propo_type_cd  \
# 0   DT30106  20250916      362.0              2             1
# 1   DT30106  20250916      366.0              1             1
# 2   DT30106  20250922      476.0              2             1
# 3   DT30106  20250922      488.0              1             1
# 4   DT30106  20250912      295.0              2             1
# ..      ...       ...        ...            ...           ...
# 95  DT30106  20250922      479.0              1             1
# 96  DT30106  20250922      502.0            NaN           NaN
# 97  DT30106  20250922      505.0            NaN           NaN
# ...

# %% [markdown]
# ### TMKR_L

# %%
import pyodbc
import pandas as pd

SERVER = "6orm62c43rguff2mpdxwqy76tu-3meqk2mii2pehfjxfscngx5a6e.datawarehouse.fabric.microsoft.com"
DATABASE = "TMKR_L"

conn_str = f"""
DRIVER={{ODBC Driver 17 for SQL Server}};
SERVER={SERVER},1433;
DATABASE={DATABASE};
Encrypt=yes;
TrustServerCertificate=no;
Authentication=ActiveDirectoryInteractive;
Connection Timeout=30;
"""

conn = pyodbc.connect(conn_str)

df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\839450372.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
#   current_db
# 0     TMKR_L

# %%
cursor = conn.cursor()
cursor.execute(f"USE [{DATABASE}]")
cursor.close()

tmkr_l_df = pd.read_sql("""
SELECT 
    TABLE_SCHEMA,
    TABLE_NAME,
    TABLE_TYPE
FROM INFORMATION_SCHEMA.TABLES
ORDER BY TABLE_SCHEMA, TABLE_NAME;
""", conn)

tmkr_l_df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\2884869036.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tmkr_l_df = pd.read_sql("""
#     TABLE_SCHEMA                       TABLE_NAME  TABLE_TYPE
# 0            dbo                         L_SVC_CR  BASE TABLE
# 1            dbo                         T_SVC_CR  BASE TABLE
# 2            dbo                          co_code  BASE TABLE
# 3            dbo                       co_company  BASE TABLE
# 4            dbo                         co_group  BASE TABLE
# ..           ...                              ...         ...
# 177          sys  managed_delta_table_checkpoints        VIEW
# 178          sys        managed_delta_table_forks        VIEW
# 179          sys    managed_delta_table_log_files        VIEW
# ...

# %% [markdown]
# ### TMKR_W

# %%
import pyodbc
import pandas as pd

SERVER = "6orm62c43rguff2mpdxwqy76tu-3meqk2mii2pehfjxfscngx5a6e.datawarehouse.fabric.microsoft.com"
DATABASE = "TMKR_W"

conn_str = f"""
DRIVER={{ODBC Driver 17 for SQL Server}};
SERVER={SERVER},1433;
DATABASE={DATABASE};
Encrypt=yes;
TrustServerCertificate=no;
Authentication=ActiveDirectoryInteractive;
Connection Timeout=30;
"""

conn = pyodbc.connect(conn_str)

df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\839450372.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
#   current_db
# 0     TMKR_L

# %%
cursor = conn.cursor()
cursor.execute(f"USE [{DATABASE}]")
cursor.close()

tmkr_w_df = pd.read_sql("""
SELECT 
    TABLE_SCHEMA,
    TABLE_NAME,
    TABLE_TYPE
FROM INFORMATION_SCHEMA.TABLES
ORDER BY TABLE_SCHEMA, TABLE_NAME;
""", conn)

tmkr_w_df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\681686325.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tmkr_w_df = pd.read_sql("""
#     TABLE_SCHEMA                       TABLE_NAME  TABLE_TYPE
# 0            dbo                         L_SVC_CR  BASE TABLE
# 1            dbo                         T_SVC_CR  BASE TABLE
# 2            dbo                          co_code  BASE TABLE
# 3            dbo                       co_company  BASE TABLE
# 4            dbo                         co_group  BASE TABLE
# ..           ...                              ...         ...
# 177          sys  managed_delta_table_checkpoints        VIEW
# 178          sys        managed_delta_table_forks        VIEW
# 179          sys    managed_delta_table_log_files        VIEW
# ...

# %% [markdown]
# ### TMKR_W_CUSTOMER

# %% [markdown]
# ### TMKR_W_PARTS

# %%
import pyodbc
import pandas as pd

SERVER = "6orm62c43rguff2mpdxwqy76tu-3meqk2mii2pehfjxfscngx5a6e.datawarehouse.fabric.microsoft.com"
DATABASE = "TMKR_W_PARTS"

conn_str = f"""
DRIVER={{ODBC Driver 17 for SQL Server}};
SERVER={SERVER},1433;
DATABASE={DATABASE};
Encrypt=yes;
TrustServerCertificate=no;
Authentication=ActiveDirectoryInteractive;
Connection Timeout=30;
"""

conn = pyodbc.connect(conn_str)

df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\813252050.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
#      current_db
# 0  TMKR_W_PARTS

# %%
cursor = conn.cursor()
cursor.execute(f"USE [{DATABASE}]")
cursor.close()

tmkr_w_parts_df = pd.read_sql("""
SELECT 
    TABLE_SCHEMA,
    TABLE_NAME,
    TABLE_TYPE
FROM INFORMATION_SCHEMA.TABLES
ORDER BY TABLE_SCHEMA, TABLE_NAME;
""", conn)

tmkr_w_parts_df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\2971069426.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tmkr_w_parts_df = pd.read_sql("""
#      TABLE_SCHEMA                        TABLE_NAME  TABLE_TYPE
# 0             dbo                      기준_데이터업데이트날짜  BASE TABLE
# 1             dbo                        기준_부품서비스센터  BASE TABLE
# 2             dbo                           기준_출고일자  BASE TABLE
# 3             dbo                     정보_부품출고제안서_v2  BASE TABLE
# 4   queryinsights             exec_requests_history        VIEW
# 5   queryinsights             exec_sessions_history        VIEW
# 6   queryinsights            frequently_run_queries        VIEW
# 7   queryinsights              long_running_queries        VIEW
# 8   queryinsights                 sql_pool_insights        VIEW
# ...

# %% [markdown]
# ### TMKR_W_PARTS(IMS)

# %%
import pyodbc
import pandas as pd

SERVER = "6orm62c43rguff2mpdxwqy76tu-3meqk2mii2pehfjxfscngx5a6e.datawarehouse.fabric.microsoft.com"
DATABASE = "TMKR_W_PARTS(IMS)"

conn_str = f"""
DRIVER={{ODBC Driver 17 for SQL Server}};
SERVER={SERVER},1433;
DATABASE={DATABASE};
Encrypt=yes;
TrustServerCertificate=no;
Authentication=ActiveDirectoryInteractive;
Connection Timeout=30;
"""

conn = pyodbc.connect(conn_str)

df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\3962101568.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
#         current_db
# 0  TMKR_W_CUSTOMER

# %%
cursor = conn.cursor()
cursor.execute(f"USE [{DATABASE}]")
cursor.close()

tmkr_w_parts_ims_df = pd.read_sql("""
SELECT 
    TABLE_SCHEMA,
    TABLE_NAME,
    TABLE_TYPE
FROM INFORMATION_SCHEMA.TABLES
ORDER BY TABLE_SCHEMA, TABLE_NAME;
""", conn)

tmkr_w_parts_ims_df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\2950017268.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tmkr_w_parts_ims_df = pd.read_sql("""
#      TABLE_SCHEMA                        TABLE_NAME  TABLE_TYPE
# 0             dbo                      기준_데이터업데이트날짜  BASE TABLE
# 1             dbo                        기준_부품서비스센터  BASE TABLE
# 2             dbo                           기준_출고일자  BASE TABLE
# 3             dbo                     정보_부품출고제안서_v2  BASE TABLE
# 4   queryinsights             exec_requests_history        VIEW
# 5   queryinsights             exec_sessions_history        VIEW
# 6   queryinsights            frequently_run_queries        VIEW
# 7   queryinsights              long_running_queries        VIEW
# 8   queryinsights                 sql_pool_insights        VIEW
# ...

# %% [markdown]
# ### TMKR_W_SALES

# %%
import pyodbc
import pandas as pd

SERVER = "6orm62c43rguff2mpdxwqy76tu-3meqk2mii2pehfjxfscngx5a6e.datawarehouse.fabric.microsoft.com"
DATABASE = "TMKR_W_SALES"

conn_str = f"""
DRIVER={{ODBC Driver 17 for SQL Server}};
SERVER={SERVER},1433;
DATABASE={DATABASE};
Encrypt=yes;
TrustServerCertificate=no;
Authentication=ActiveDirectoryInteractive;
Connection Timeout=30;
"""

conn = pyodbc.connect(conn_str)

df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\1312140838.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
#      current_db
# 0  TMKR_W_SALES

# %%
cursor = conn.cursor()
cursor.execute(f"USE [{DATABASE}]")
cursor.close()

tmkr_w_sales_df = pd.read_sql("""
SELECT 
    TABLE_SCHEMA,
    TABLE_NAME,
    TABLE_TYPE
FROM INFORMATION_SCHEMA.TABLES
ORDER BY TABLE_SCHEMA, TABLE_NAME;
""", conn)

tmkr_w_sales_df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\2374931223.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tmkr_w_sales_df = pd.read_sql("""
#      TABLE_SCHEMA                        TABLE_NAME  TABLE_TYPE
# 0             dbo                        기준_WSH_브랜치  BASE TABLE
# 1             dbo                      기준_계약_순번기준일시  BASE TABLE
# 2             dbo                         기준_계약_전시장  BASE TABLE
# 3             dbo                        기준_계약_차량사양  BASE TABLE
# 4             dbo                     기준_재고_PDI_PPO  BASE TABLE
# 5             dbo                        기준_재고_리콜내역  BASE TABLE
# 6             dbo                        기준_재고_배정내용  BASE TABLE
# 7             dbo                         기준_재고_브랜치  BASE TABLE
# 8             dbo                        기준_재고_차량사양  BASE TABLE
# ...

# %% [markdown]
# ## 2. connect BP/KTWS

# %%
import pyodbc
import pandas as pd

SERVER = "6orm62c43rguff2mpdxwqy76tu-xhehnpiu2bautgglhximxpyqca.datawarehouse.fabric.microsoft.com"

conn_str = f"""
DRIVER={{ODBC Driver 17 for SQL Server}};
SERVER={SERVER},1433;
Encrypt=yes;
TrustServerCertificate=no;
Authentication=ActiveDirectoryInteractive;
Connection Timeout=30;
"""

conn = pyodbc.connect(conn_str)

df_db = pd.read_sql("""
SELECT name
FROM sys.databases
ORDER BY name
""", conn)

df_db
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\2283993718.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_db = pd.read_sql("""
#                                           name
# 0                    DataflowsStagingLakehouse
# 1                    DataflowsStagingWarehouse
# 2                                        KPI_L
# 3                                        KPI_W
# 4                                       master
# 5  StagingLakehouseForDataflows_20250812005148
# 6  StagingWarehouseForDataflows_20250812005211

# %%
import pyodbc
import pandas as pd

SERVER = "6orm62c43rguff2mpdxwqy76tu-xhehnpiu2bautgglhximxpyqca.datawarehouse.fabric.microsoft.com"
DATABASE = "KPI_L"

conn_str = f"""
DRIVER={{ODBC Driver 17 for SQL Server}};
SERVER={SERVER},1433;
DATABASE={DATABASE};
Encrypt=yes;
TrustServerCertificate=no;
Authentication=ActiveDirectoryInteractive;
Connection Timeout=30;
"""

conn = pyodbc.connect(conn_str)

df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
df

cursor = conn.cursor()
cursor.execute(f"USE [{DATABASE}]")
cursor.close()

kpi_l_df = pd.read_sql("""
SELECT 
    TABLE_SCHEMA,
    TABLE_NAME,
    TABLE_TYPE
FROM INFORMATION_SCHEMA.TABLES
ORDER BY TABLE_SCHEMA, TABLE_NAME;
""", conn)

kpi_l_df
# Out:
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\3609988323.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT DB_NAME() AS current_db", conn)
# C:\Users\LouisLee(이시호)\AppData\Local\Temp\ipykernel_27032\3609988323.py:26: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   kpi_l_df = pd.read_sql("""
#      TABLE_SCHEMA                        TABLE_NAME  TABLE_TYPE
# 0             dbo                     a_bilogo_pics  BASE TABLE
# 1             dbo                  a_bilogo_pics_v2  BASE TABLE
# 2             dbo                        co_company  BASE TABLE
# 3             dbo                 l_co_calendar_stg  BASE TABLE
# ...

# %% [markdown]
# ## 3. connect Karete

# %%
import pyodbc
import pandas as pd

SERVER = "6orm62c43rguff2mpdxwqy76tu-kp6lscr4iunung5p66mov6kcka.datawarehouse.fabric.microsoft.com"

conn_str = f"""
DRIVER={{ODBC Driver 17 for SQL Server}};
SERVER={SERVER},1433;
Encrypt=yes;
TrustServerCertificate=no;
Authentication=ActiveDirectoryInteractive;
Connection Timeout=30;
"""

conn = pyodbc.connect(conn_str)

df_db = pd.read_sql("""
SELECT name
FROM sys.databases
ORDER BY name
""", conn)

df_db
